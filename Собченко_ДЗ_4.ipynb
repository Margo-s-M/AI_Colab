# %% [markdown]
# <a href="https://colab.research.google.com/github/Margo-s-M/AI_Colab/blob/main/%D0%A1%D0%BE%D0%B1%D1%87%D0%B5%D0%BD%D0%BA%D0%BE_%D0%94%D0%97_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Імпорт модулів та даних

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module2/data/possum.csv")

# %%
df.head()
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3     4     1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4     5     1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
#
#    earconch   eye  chest  belly
# 0      54.5  15.2   28.0   36.0
# 1      51.2  16.0   28.5   33.0
# 2      51.9  15.5   30.0   34.0
# 3      52.2  15.2   28.0   34.0
# 4      53.2  15.1   28.5   33.0

# %%
df.shape
# Out:
# (104, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   case      104 non-null    int64
#  1   site      104 non-null    int64
#  2   Pop       104 non-null    object
#  3   sex       104 non-null    object
#  4   age       102 non-null    float64
#  5   hdlngth   104 non-null    float64
#  6   skullw    104 non-null    float64
#  7   totlngth  104 non-null    float64
#  8   taill     104 non-null    float64
#  9   footlgth  103 non-null    float64
#  10  earconch  104 non-null    float64
#  11  eye       104 non-null    float64
#  12  chest     104 non-null    float64
#  13  belly     104 non-null    float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 11.5+ KB

# %% [markdown]
# числові значення в case site age sex hdlngth skull totlngth taill footlngth earconch eye chest belly
#
# ```
# # Выбран кодовый формат
# ```

# %% [markdown]
# # Завдання 1
# Виведіть основні числові характеристики для числових ознак

# %% [markdown]
# вибрати колонки int64 float64 include= дозволяє обрати тільки ті колонки які потрібні

# %%
numeric_df = df.select_dtypes(include=[np.number])
numeric_df
# Out:
#      case  site  age  hdlngth  skullw  totlngth  taill  footlgth  earconch  \
# 0       1     1  8.0     94.1    60.4      89.0   36.0      74.5      54.5
# 1       2     1  6.0     92.5    57.6      91.5   36.5      72.5      51.2
# 2       3     1  6.0     94.0    60.0      95.5   39.0      75.4      51.9
# 3       4     1  6.0     93.2    57.1      92.0   38.0      76.1      52.2
# 4       5     1  2.0     91.5    56.3      85.5   36.0      71.0      53.2
# ..    ...   ...  ...      ...     ...       ...    ...       ...       ...
# 99    100     7  1.0     89.5    56.0      81.5   36.5      66.0      46.8
# 100   101     7  1.0     88.6    54.7      82.5   39.0      64.4      48.0
# 101   102     7  6.0     92.4    55.0      89.0   38.0      63.5      45.4
# 102   103     7  4.0     91.5    55.2      82.5   36.5      62.9      45.9
# 103   104     7  3.0     93.6    59.9      89.0   40.0      67.6      46.0
#
#       eye  chest  belly
# 0    15.2   28.0   36.0
# ...

# %%
summary_stats = numeric_df.describe()
summary_stats
# Out:
#              case        site         age     hdlngth      skullw    totlngth  \
# count  104.000000  104.000000  102.000000  104.000000  104.000000  104.000000
# mean    52.500000    3.625000    3.833333   92.602885   56.883654   87.088462
# std     30.166206    2.349086    1.909244    3.573349    3.113426    4.310549
# min      1.000000    1.000000    1.000000   82.500000   50.000000   75.000000
# 25%     26.750000    1.000000    2.250000   90.675000   54.975000   84.000000
# 50%     52.500000    3.000000    3.000000   92.800000   56.350000   88.000000
# 75%     78.250000    6.000000    5.000000   94.725000   58.100000   90.000000
# max    104.000000    7.000000    9.000000  103.100000   68.600000   96.500000
#
#             taill    footlgth    earconch         eye       chest       belly
# count  104.000000  103.000000  104.000000  104.000000  104.000000  104.000000
# mean    37.009615   68.459223   48.130769   15.046154   27.000000   32.586538
# ...

# %%
summary_stats["median"] = numeric_df.median()
summary_stats["var"] = numeric_df.var()
summary_stats["missing_values"] = numeric_df.isna().sum()
summary_stats
# Out:
#              case        site         age     hdlngth      skullw    totlngth  \
# count  104.000000  104.000000  102.000000  104.000000  104.000000  104.000000
# mean    52.500000    3.625000    3.833333   92.602885   56.883654   87.088462
# std     30.166206    2.349086    1.909244    3.573349    3.113426    4.310549
# min      1.000000    1.000000    1.000000   82.500000   50.000000   75.000000
# 25%     26.750000    1.000000    2.250000   90.675000   54.975000   84.000000
# 50%     52.500000    3.000000    3.000000   92.800000   56.350000   88.000000
# 75%     78.250000    6.000000    5.000000   94.725000   58.100000   90.000000
# max    104.000000    7.000000    9.000000  103.100000   68.600000   96.500000
#
#             taill    footlgth    earconch         eye       chest       belly  \
# count  104.000000  103.000000  104.000000  104.000000  104.000000  104.000000
# mean    37.009615   68.459223   48.130769   15.046154   27.000000   32.586538
# ...

# %% [markdown]
# # Завдання 2
# Проаналізуйте стовпчик `case`, чи є він інформативним?

# %% [markdown]
# case не являється колонкою яка має в собі важливу інформацію, на виглад дублювання індексу зі зміщенням , більше схоже на нумерацію від 1 до 104 в той же час індекс від 0 до 103 , всеж таки вважаю що видаляти її не потрібно оскільки з індексом працюють фахівці в галузі айті а з усією таблицею працюють науковці і т.д. тож дана колонка на мою дуску для них.

# %% [markdown]
# # Завдання 3
# Очистіть дані від викидів. Виведіть очищений датафрейм

# %% [markdown]
# # Завдання 4
# Для одного з числових стовпчиків вивести гістограму та ящик з вусами

# %%
df['skullw'].plot(kind='hist', bins=31, figsize=(14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['skullw'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# # Завдання 5
# Намалюйте матрицб кореляцій. Для найбільш корельованих ознак намалюйте точкову діаграму.

# %% [markdown]
# # Завдання 6
# Для 4-ох числових ознак на вибір намалюйте ящики з вусами згрупованими по статі. Подумайте чи є вплив статі на розміри опосума
